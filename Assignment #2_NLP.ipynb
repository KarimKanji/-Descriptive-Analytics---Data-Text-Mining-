# %%
import nltk
from nltk import pos_tag
from nltk.chunk import RegexpParser
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')

# List of 100 Swedish words
swedish_words = [
    "gul", "ros", "blå", "grön", "röd", "vit", "svart", "brun", "orange", "lila",
    "hund", "katt", "fågel", "apa", "elefant", "lejon", "tiger", "björn", "zebra", "antilop",
    "bord", "stol", "soffa", "säng", "byrå", "bokhylla", "garderob", "lampa", "television", "dator",
    "mamma", "pappa", "barn", "farfar", "farmor", "mormor", "morbror", "farbror", "kusin", "moster",
    "hus", "lägenhet", "radhus", "villa", "fästning", "palats", "slott", "herrgård", "gård", "koja",
    "apple", "banana", "apelsin", "päron", "kiwi", "ananas", "jordgubbar", "hallon", "blåbär", "grapefrukt",
    "bok", "penna", "papper", "blyertspenna", "suddgummi", "raderingspenna", "tejp", "kalender", "anteckningsblock", "pärm",
    "boll", "bats", "mål", "handskar", "träningsutrustning", "skor", "kläder", "keps", "sjal", "väst",
    "solsken", "regn", "snö", "hagel", "åska", "dimma", "dis", "frost", "blåst", "väder",
    "buss", "bil", "flygplan", "tåg", "cykel", "skoter", "båt", "rulleblad", "skateboard", "surfbräda"
]

# Annotating the Swedish words with POS tags
swedish_words_pos = pos_tag(swedish_words)

# Defining the chunk grammar
chunk_grammar = "NP: {<NNP><VB><NN>}"
chunk_parser = RegexpParser(chunk_grammar)
chunked = chunk_parser.parse(swedish_words_pos)

for chunk in chunked:
    # if hasattr(chunk, "label"):
    #     print(chunk.label(), " ".join(c[0] for c in chunk))
    print(chunk)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-1-6eac751e964e> in <module>
#      20
#      21 # Annotating the Swedish words with POS tags
# ---> 22 swedish_words_pos = pos_tag(swedish_words)
#      23
#      24 # Defining the chunk grammar
#
# /usr/local/lib/python3.8/dist-packages/nltk/tag/__init__.py in pos_tag(tokens, tagset, lang)
#     163     :rtype: list(tuple(str, str))
#     164     """
# --> 165     tagger = _get_tagger(lang)
#     166     return _pos_tag(tokens, tagset, tagger, lang)
#     167
#
# /usr/local/lib/python3.8/dist-packages/nltk/tag/__init__.py in _get_tagger(lang)
#     105         tagger.load(ap_russian_model_loc)
#     106     else:
# --> 107         tagger = PerceptronTagger()
#     108     return tagger
#     109
#
# /usr/local/lib/python3.8/dist-packages/nltk/tag/perceptron.py in __init__(self, load)
#     165         if load:
# ...
